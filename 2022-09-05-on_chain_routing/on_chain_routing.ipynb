# %% [markdown]
# # On-Chain Arbitrage Routing
#
# - Pre-processing arbitrage routes for a single chain
# - Assets can be identified by address on-chain, and all dex pairs can be directly interacted with without bridging/depositing/withdrawing
# - Assumed all long holdings are USDT, therefore all arbitrages must begin and terminate with USDT

# %%
import pandas as pd
import numpy as np
import json

usdt_address = r"0x382bB369d343125BfB2117af9c149795C6C65C50".lower()
chain_name = 'okx'
product_ids = ['aiSwap', 'cherrySwap', 'jswapFinance', 'kSwap', 'pandaSwap']

# %%
def load_pairs_for_product(chain_name, product_id):
  filename = f'input/pairs/{chain_name}-{product_id}.json'
  with open(filename, 'r') as f:
    data_json = json.load(f)
  df = pd.json_normalize(data_json['data'])
  df = df.drop('level_0', axis = 1)
  df = df.groupby(['index']).max().reset_index()
  df['productId'] = product_id
  return df

def load_pairs_for_products(chain_name, product_ids):
  return pd.concat(map(lambda product_id: load_pairs_for_product(chain_name, product_id), product_ids))

df_pairs = load_pairs_for_products(chain_name, product_ids)
df_pairs.head()
# Out:
#    index                                     address  \
# 0      1  0xf6a14934ed35e1e2bb448555baaf37adb91297ed
# 1      2  0x7b44eef5060a4b1007705cfccb40a866100180ff
# 2      3  0x44e8a805f8c06de4dcedf3cd169688a6a5fceaba
# 3      6  0x3cca939888e796c104434bd120a3ba0d10f1834b
# 4     14  0x0c6cdba862b6c5a82f7297934043a059e0ef2c54
#
#                                       token_0 name_0 symbol_0  decimals_0  \
# 0  0x3212606f74cc59656e1ec6f587fca61ba3b85eb0   SFGK     SFGK        18.0
# 1  0x21cde7e32a6caf4742d00d44b07279e7596d26b9   DAIK     DAIK        18.0
# 2  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 3  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 4  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
#
#                                       token_1       name_1 symbol_1  \
# 0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 1  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 2  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 3  0x54e4622dc504176b3bb432dccaf504569699a7ff         BTCK     BTCK
# 4  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c         ETHK     ETHK
#
#    decimals_1 productId
# 0        18.0    aiSwap
# 1        18.0    aiSwap
# 2        18.0    aiSwap
# 3        18.0    aiSwap
# 4        18.0    aiSwap

# %% [markdown]
# ### Number of pairs per product

# %%
df_pairs.groupby(by = 'productId').count()['index']
# Out:
# productId
# aiSwap            6
# cherrySwap      114
# jswapFinance    159
# kSwap            32
# pandaSwap        14
# Name: index, dtype: int64

# %% [markdown]
# ## USDT Pair Routes
#
# Simply selects all the pairs with a USDT side, and groups them by the other side.

# %% [markdown]
# ### 1. Get all pairs against USDT

# %%
df_pairs_usdt = df_pairs[(df_pairs['token_0'] == usdt_address) | (df_pairs['token_1'] == usdt_address)]
df_pairs_usdt.head()
# Out:
#    index                                     address  \
# 2      3  0x44e8a805f8c06de4dcedf3cd169688a6a5fceaba
# 3      6  0x3cca939888e796c104434bd120a3ba0d10f1834b
# 4     14  0x0c6cdba862b6c5a82f7297934043a059e0ef2c54
# 0      0  0xf3098211d012ff5380a03d80f150ac6e5753caa8
# 1      1  0x94e01843825ef85ee183a711fa7ae0c5701a731a
#
#                                       token_0 name_0 symbol_0  decimals_0  \
# 2  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 3  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 4  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 0  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 1  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
#
#                                       token_1       name_1 symbol_1  \
# 2  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 3  0x54e4622dc504176b3bb432dccaf504569699a7ff         BTCK     BTCK
# 4  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c         ETHK     ETHK
# 0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 1  0x54e4622dc504176b3bb432dccaf504569699a7ff         BTCK     BTCK
#
#    decimals_1   productId
# 2        18.0      aiSwap
# 3        18.0      aiSwap
# 4        18.0      aiSwap
# 0        18.0  cherrySwap
# 1        18.0  cherrySwap

# %% [markdown]
# ### 2. Get all USDT pairs with at least one other pair between the same assets
#
# Note:
#
# - The other pairs can have the non-USDT token on either side (e.g. be USDT/X or X/USDT)
# - They may be on the same dex, or a different dex

# %%
df_pairs_usdt_with_other = df_pairs_usdt.copy()
df_pairs_usdt_with_other['token_other'] = df_pairs_usdt_with_other.apply(lambda row: row['token_1'] if row['token_0'] == usdt_address else row['token_0'], axis = 1)
df_pairs_usdt_with_other['symbol_other'] = df_pairs_usdt_with_other.apply(lambda row: row['symbol_1'] if row['token_0'] == usdt_address else row['symbol_0'], axis = 1)

df_pairs_usdt_by_token = df_pairs_usdt_with_other.groupby('token_other')['token_other'].size()

set_pairs_usdt_addresses = set(df_pairs_usdt_by_token[df_pairs_usdt_by_token > 1].index.values)

df_pairs_usdt_arbs = df_pairs_usdt_with_other[df_pairs_usdt_with_other.apply(lambda row: row['token_other'] in set_pairs_usdt_addresses, axis = 1)]
df_pairs_usdt_arbs = df_pairs_usdt_arbs.sort_values('token_other')

del df_pairs_usdt_with_other
del df_pairs_usdt_by_token
del set_pairs_usdt_addresses

df_pairs_usdt_arbs.head()
# Out:
#     index                                     address  \
# 25    149  0xb6d297c6b9a7863ed67b67211ca3e356a5f02b92
# 30    557  0x9b287c7b4b4ae3843a129815b7ad417e19de8bff
# 26    150  0x50b942a347564063b40e42e72a86650d86cce776
# 32    559  0x453377749a1d515eb6d99f1bdfd987785e55943e
# 14     55  0xe9313b7dea9cbabd2df710c25bef44a748ab38a9
#
#                                        token_0 name_0 symbol_0  decimals_0  \
# 25  0x00505505a7576d6734704fabb16f41924e3e384b   TRXK     TRXK        18.0
# 30  0x00505505a7576d6734704fabb16f41924e3e384b   TRXK     TRXK        18.0
# 26  0x18d103b7066aeedb6005b78a462ef9027329b1ea   BCHK     BCHK        18.0
# 32  0x18d103b7066aeedb6005b78a462ef9027329b1ea   BCHK     BCHK        18.0
# 14  0x21cde7e32a6caf4742d00d44b07279e7596d26b9   DAIK     DAIK        18.0
#
#                                        token_1 name_1 symbol_1  decimals_1  \
# 25  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 30  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 26  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 32  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 14  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
#
#        productId                                 token_other symbol_other
# 25  jswapFinance  0x00505505a7576d6734704fabb16f41924e3e384b         TRXK
# 30    cherrySwap  0x00505505a7576d6734704fabb16f41924e3e384b         TRXK
# 26  jswapFinance  0x18d103b7066aeedb6005b78a462ef9027329b1ea         BCHK
# 32    cherrySwap  0x18d103b7066aeedb6005b78a462ef9027329b1ea         BCHK
# 14  jswapFinance  0x21cde7e32a6caf4742d00d44b07279e7596d26b9         DAIK

# %% [markdown]
# ### Analysis: How many distinct pairs are there?

# %%
df_pairs_usdt_arbs_grouped = df_pairs_usdt_arbs.groupby(by = ['token_other', 'symbol_other'])

df_pairs_usdt_arbs_groups = pd.DataFrame(df_pairs_usdt_arbs_grouped.size(), columns = ['count'])
df_pairs_usdt_arbs_groups['productIds'] = df_pairs_usdt_arbs_grouped['productId'].apply(lambda product_ids: ', '.join(sorted(product_ids)))
df_pairs_usdt_arbs_groups = df_pairs_usdt_arbs_groups.sort_values(by = 'count', ascending = False)

del df_pairs_usdt_arbs_grouped

df_pairs_usdt_arbs_groups
# Out:
#                                                          count  \
# token_other                                symbol_other
# 0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15 WOKT              5
# 0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c ETHK              5
# 0x54e4622dc504176b3bb432dccaf504569699a7ff BTCK              5
# 0xdf54b6c6195ea4d948d03bfd818d365cf175cfc2 OKB               4
# 0x59d226bb0a4d74274d4354ebb6a0e1a1aa5175b6 UNIK              3
# 0xa715f624eb32c6c960b0e044b10cde585d5f5984 XRPK              3
# 0xfa520efc34c81bfc1e3dd48b7fe9ff326049f986 LTCK              3
# 0x5ab622494ab7c5e81911558c9552dbd517f403fb Celt              2
# 0x79b627bc95fa5b36eca53eb39c3cdf43aafdd10f ORG               2
# 0x18d103b7066aeedb6005b78a462ef9027329b1ea BCHK              2
# 0x99970778e2715bbc9cf8fb83d10dcbc2d2d551a3 ETCK              2
# 0x3f8969be2fc0770dcc174968e4b4ff146e0acdaf FILK              2
# 0xbeb67de6cc5af652b2d9b0235750ed70f5a2cb0d LINKK             2
# 0xc3bdfee6186849d5509601045af4af567a001c94 Glory             2
# 0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85 USDC              2
# 0xdcac52e001f5bd413aa6ea83956438f29098166b USDK              2
# 0x332730a4f6e03d9c55829435f10360e13cfa41ff BUSD              2
# 0x21cde7e32a6caf4742d00d44b07279e7596d26b9 DAIK              2
# 0x00505505a7576d6734704fabb16f41924e3e384b TRXK              2
#
#                                                                                                 productIds
# token_other                                symbol_other
# 0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15 WOKT          aiSwap, cherrySwap, jswapFinance, kSwap, panda...
# 0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c ETHK          aiSwap, cherrySwap, jswapFinance, kSwap, panda...
# 0x54e4622dc504176b3bb432dccaf504569699a7ff BTCK          aiSwap, cherrySwap, jswapFinance, kSwap, panda...
# 0xdf54b6c6195ea4d948d03bfd818d365cf175cfc2 OKB                  cherrySwap, jswapFinance, kSwap, pandaSwap
# 0x59d226bb0a4d74274d4354ebb6a0e1a1aa5175b6 UNIK                            cherrySwap, jswapFinance, kSwap
# 0xa715f624eb32c6c960b0e044b10cde585d5f5984 XRPK                            cherrySwap, jswapFinance, kSwap
# 0xfa520efc34c81bfc1e3dd48b7fe9ff326049f986 LTCK                            cherrySwap, jswapFinance, kSwap
# 0x5ab622494ab7c5e81911558c9552dbd517f403fb Celt                                   cherrySwap, jswapFinance
# 0x79b627bc95fa5b36eca53eb39c3cdf43aafdd10f ORG                                           cherrySwap, kSwap
# 0x18d103b7066aeedb6005b78a462ef9027329b1ea BCHK                                   cherrySwap, jswapFinance
# 0x99970778e2715bbc9cf8fb83d10dcbc2d2d551a3 ETCK                                   cherrySwap, jswapFinance
# 0x3f8969be2fc0770dcc174968e4b4ff146e0acdaf FILK                                   cherrySwap, jswapFinance
# 0xbeb67de6cc5af652b2d9b0235750ed70f5a2cb0d LINKK                                  cherrySwap, jswapFinance
# 0xc3bdfee6186849d5509601045af4af567a001c94 Glory                                     cherrySwap, pandaSwap
# 0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85 USDC                                      cherrySwap, pandaSwap
# 0xdcac52e001f5bd413aa6ea83956438f29098166b USDK                                   cherrySwap, jswapFinance
# 0x332730a4f6e03d9c55829435f10360e13cfa41ff BUSD                                      cherrySwap, pandaSwap
# 0x21cde7e32a6caf4742d00d44b07279e7596d26b9 DAIK                                   cherrySwap, jswapFinance
# 0x00505505a7576d6734704fabb16f41924e3e384b TRXK                                   cherrySwap, jswapFinance

# %% [markdown]
# ## USDT Triangular Arbitrage Routes
#
# https://en.wikipedia.org/wiki/Triangular_arbitrage

# %% [markdown]
# ### 1. Get all pairs against USDT

# %%
df_pairs_usdt = df_pairs[(df_pairs['token_0'] == usdt_address) | (df_pairs['token_1'] == usdt_address)]
df_pairs_usdt.head()
# Out:
#    index                                     address  \
# 2      3  0x44e8a805f8c06de4dcedf3cd169688a6a5fceaba
# 3      6  0x3cca939888e796c104434bd120a3ba0d10f1834b
# 4     14  0x0c6cdba862b6c5a82f7297934043a059e0ef2c54
# 0      0  0xf3098211d012ff5380a03d80f150ac6e5753caa8
# 1      1  0x94e01843825ef85ee183a711fa7ae0c5701a731a
#
#                                       token_0 name_0 symbol_0  decimals_0  \
# 2  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 3  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 4  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 0  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
# 1  0x382bb369d343125bfb2117af9c149795c6c65c50   USDT     USDT        18.0
#
#                                       token_1       name_1 symbol_1  \
# 2  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 3  0x54e4622dc504176b3bb432dccaf504569699a7ff         BTCK     BTCK
# 4  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c         ETHK     ETHK
# 0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15  Wrapped OKT     WOKT
# 1  0x54e4622dc504176b3bb432dccaf504569699a7ff         BTCK     BTCK
#
#    decimals_1   productId
# 2        18.0      aiSwap
# 3        18.0      aiSwap
# 4        18.0      aiSwap
# 0        18.0  cherrySwap
# 1        18.0  cherrySwap

# %% [markdown]
# ### 2. Get the set of all tokens with a USDT pair

# %%
set_tokens_with_usdt_pairs = set(pd.concat([df_pairs_usdt['token_0'], df_pairs_usdt['token_1']], axis = 0))
set_tokens_with_usdt_pairs.discard(usdt_address)

print(f'Number of tokens = {len(set_tokens_with_usdt_pairs)}')
# Out:
# Number of tokens = 106

# %% [markdown]
# ### 3. Get all pairs NOT against USDT

# %%
df_pairs_non_usdt = df_pairs[(df_pairs['token_0'] != usdt_address) & (df_pairs['token_1'] != usdt_address)]
df_pairs_non_usdt.head()
# Out:
#    index                                     address  \
# 0      1  0xf6a14934ed35e1e2bb448555baaf37adb91297ed
# 1      2  0x7b44eef5060a4b1007705cfccb40a866100180ff
# 5     15  0x13b3e85f115a2938be5345c62e68bba5c858f71d
# 3      3  0x8e68c0216562bcea5523b27ec6b9b6e1cccbbf88
# 7     26  0x351e76d3339a143eb7b1709b4514404022ccc35e
#
#                                       token_0            name_0 symbol_0  \
# 0  0x3212606f74cc59656e1ec6f587fca61ba3b85eb0              SFGK     SFGK
# 1  0x21cde7e32a6caf4742d00d44b07279e7596d26b9              DAIK     DAIK
# 5  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15       Wrapped OKT     WOKT
# 3  0x8179d97eb6488860d816e3ecafe694a4153f216c  CherrySwap Token      CHE
# 7  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15       Wrapped OKT     WOKT
#
#    decimals_0                                     token_1  \
# 0        18.0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15
# 1        18.0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15
# 5        18.0  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c
# 3        18.0  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15
# 7        18.0  0xda3a3002c7af6b465b3bf06ce5eac974f2515b5f
#
#                    name_1 symbol_1  decimals_1   productId
# 0             Wrapped OKT     WOKT        18.0      aiSwap
# 1             Wrapped OKT     WOKT        18.0      aiSwap
# 5                    ETHK     ETHK        18.0      aiSwap
# 3             Wrapped OKT     WOKT        18.0  cherrySwap
# 7  hard to write contract  MiNiCHE        18.0  cherrySwap

# %% [markdown]
# ### 4. Forall non-USDT pairs, find those in which both sides have a USDT pair

# %%
token_symbol_by_address = pd.concat([
  df_pairs_non_usdt[['token_0', 'symbol_0']].rename({'token_0':'token','symbol_0':'symbol'}, axis = 1).set_index('token'),
  df_pairs_non_usdt[['token_1', 'symbol_1']].rename({'token_1':'token','symbol_1':'symbol'}, axis = 1).set_index('token')
]).drop_duplicates().to_dict()['symbol']

df_pairs_tri_arbs = df_pairs_non_usdt[(df_pairs_non_usdt['token_0'].isin(set_tokens_with_usdt_pairs)) & (df_pairs_non_usdt['token_1'].isin(set_tokens_with_usdt_pairs))].copy()
df_pairs_tri_arbs['group_key'] = df_pairs_tri_arbs.apply(lambda row: ','.join(sorted([row['token_0'], row['token_1']])), axis = 1)

df_pairs_tri_arbs_grouped = df_pairs_tri_arbs.groupby(by = ['group_key'])

df_pairs_tri_arbs_groups = pd.DataFrame(df_pairs_tri_arbs_grouped.size(), columns = ['count'])
df_pairs_tri_arbs_groups['pairAddresses'] = df_pairs_tri_arbs_grouped['address'].apply(lambda pair_addresses: '[' + ', '.join(sorted(pair_addresses)) + ']')
df_pairs_tri_arbs_groups['productIds'] = df_pairs_tri_arbs_grouped['productId'].apply(lambda product_ids: '[' + ', '.join(sorted(product_ids)) + ']')
df_pairs_tri_arbs_groups['token_0'] = df_pairs_tri_arbs_grouped.apply(lambda g: g.name.split(',')[0])
df_pairs_tri_arbs_groups['symbol_0'] = df_pairs_tri_arbs_groups.apply(lambda row: token_symbol_by_address[row['token_0']], axis = 1)
df_pairs_tri_arbs_groups['token_1'] = df_pairs_tri_arbs_grouped.apply(lambda g: g.name.split(',')[1])
df_pairs_tri_arbs_groups['symbol_1'] = df_pairs_tri_arbs_groups.apply(lambda row: token_symbol_by_address[row['token_1']], axis = 1)
df_pairs_tri_arbs_groups['arbLabel'] = df_pairs_tri_arbs_groups.apply(lambda row: f'USDT=>{row["symbol_0"]}=>{row["symbol_1"]}=>USDT', axis = 1)


df_pairs_tri_arbs_groups = df_pairs_tri_arbs_groups.sort_values(by = 'count', ascending = False)
df_pairs_tri_arbs_groups = df_pairs_tri_arbs_groups.reset_index().drop(columns = ['group_key'])

del token_symbol_by_address
del df_pairs_tri_arbs_grouped

df_pairs_tri_arbs_groups
# Out:
#     count                                      pairAddresses  \
# 0       3  [0xaea843a6715d091f7a5644ed4fcca479820bd18a, 0...
# 1       3  [0x24aa7ec16b1965bc3e1c68de80298b16cbc6ef92, 0...
# 2       3  [0x1290e0cd4ed25919bc7d5cf27c9a62199b1de10e, 0...
# 3       2  [0x579c3b456efe2591173cc3accbaba530e318e89f, 0...
# 4       1       [0xc577dd5fb0fcbcd65edf922cf257ec0cfe42f88a]
# 5       1       [0x4225f964eeac8c022a39e5fd1c23791e113b0c75]
# 6       1       [0x562f8cf1e7a5f72e01452c6bceebd4cd3399cb94]
# 7       1       [0x9d2220f710bdf68ac2bc6d5d27f0eda629d0a638]
# 8       1       [0x13b3e85f115a2938be5345c62e68bba5c858f71d]
# 9       1       [0xa25da5a44a65ee9bd4ea61f946cbcf15512fd52e]
# 10      1       [0x9f7965202ecec734b47b8cff8367e9058f620ae1]
# 11      1       [0x80785a8497518beae513eff9b293510e6c360c4f]
# 12      1       [0x8e68c0216562bcea5523b27ec6b9b6e1cccbbf88]
# 13      1       [0x16ca1e416b8ea7e388da0602f60482a5aa448b55]
# 14      1       [0xa2cd52377b5d955c90b36721930d190855bec309]
# 15      1       [0x7b44eef5060a4b1007705cfccb40a866100180ff]
# 16      1       [0xee2c72b4bb7b4f16de56704b3770cb7a27c3d9dc]
# 17      1       [0xb16d8681fb55f8a6e2effb58c1473af38d0f2949]
# 18      1       [0xcf7942fe6ef6efea40192187c95bb2eb36882ce7]
# 19      1       [0x8c43728634fb6f1ff4c1df2be6c815976aceac22]
# 20      1       [0xf6a14934ed35e1e2bb448555baaf37adb91297ed]
# 21      1       [0x01b00e79466919465e6f8fb2a6d433201f8330f2]
# 22      1       [0x8be8765925b52ed09b703f164d286cea4692c5ba]
# 23      1       [0x0f3b50a3dd394313412485d289615fbee353e53c]
# 24      1       [0x868b3fd4517f479b3b30a75265af934a64237567]
# 25      1       [0x57d8094db87257fa9e21b766ba9f2e89a7c4e8f1]
#
#                            productIds  \
# 0   [cherrySwap, jswapFinance, kSwap]
# 1   [cherrySwap, jswapFinance, kSwap]
# 2   [cherrySwap, jswapFinance, kSwap]
# 3          [cherrySwap, jswapFinance]
# 4                             [kSwap]
# 5                      [jswapFinance]
# 6                        [cherrySwap]
# 7                      [jswapFinance]
# 8                            [aiSwap]
# 9                             [kSwap]
# 10                        [pandaSwap]
# 11                       [cherrySwap]
# 12                       [cherrySwap]
# 13                     [jswapFinance]
# 14                       [cherrySwap]
# 15                           [aiSwap]
# 16                       [cherrySwap]
# 17                       [cherrySwap]
# 18                     [jswapFinance]
# 19                            [kSwap]
# 20                           [aiSwap]
# 21                       [cherrySwap]
# 22                       [cherrySwap]
# 23                     [jswapFinance]
# 24                       [cherrySwap]
# 25                       [cherrySwap]
#
#                                        token_0 symbol_0  \
# 0   0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 1   0x39071d9e7a52e8685f1385d6fa17babfc58ce9c3      KLT
# 2   0x54e4622dc504176b3bb432dccaf504569699a7ff     BTCK
# 3   0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 4   0x0b7035b1b32b4a8be30055efc3909e4358000527     CASH
# 5   0x5fac926bf1e638944bb16fb5b787b5ba4bc85b0a       JF
# 6   0xdcac52e001f5bd413aa6ea83956438f29098166b     USDK
# 7   0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85     USDC
# 8   0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 9   0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 10  0x8eac9d49f71a9393ed38a619038e880c86d5745c      PND
# 11  0x8179d97eb6488860d816e3ecafe694a4153f216c      CHE
# 12  0x8179d97eb6488860d816e3ecafe694a4153f216c      CHE
# 13  0x5fac926bf1e638944bb16fb5b787b5ba4bc85b0a       JF
# 14  0x5ab622494ab7c5e81911558c9552dbd517f403fb     Celt
# 15  0x21cde7e32a6caf4742d00d44b07279e7596d26b9     DAIK
# 16  0x54e4622dc504176b3bb432dccaf504569699a7ff     BTCK
# 17  0x54e4622dc504176b3bb432dccaf504569699a7ff     BTCK
# 18  0x493d8cbd9533e57d4befb17cc2ec1db76828261d      AST
# 19  0x321a3aedd97793b4dc746ce31ef6b560fd516f14      BFI
# 20  0x3212606f74cc59656e1ec6f587fca61ba3b85eb0     SFGK
# 21  0x2e2f982c3e66db8604b0a99862dd97d31ed740b3      OFI
# 22  0x2e2f982c3e66db8604b0a99862dd97d31ed740b3      OFI
# 23  0x2632256f09ef59b428c48622dc042198b9be2609   SQUIDK
# 24  0x21cde7e32a6caf4742d00d44b07279e7596d26b9     DAIK
# 25  0xdcac52e001f5bd413aa6ea83956438f29098166b     USDK
#
#                                        token_1 symbol_1  \
# 0   0xdf54b6c6195ea4d948d03bfd818d365cf175cfc2      OKB
# 1   0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 2   0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c     ETHK
# 3   0xdcac52e001f5bd413aa6ea83956438f29098166b     USDK
# 4   0x43a7d5573d0c3d0fac233c0cd1c9a73c8ce9ff72    SHARE
# 5   0x8da6da06a4902015cfe823b24c5ed486016ba3cb     YYDS
# 6   0xdf54b6c6195ea4d948d03bfd818d365cf175cfc2      OKB
# 7   0xdcac52e001f5bd413aa6ea83956438f29098166b     USDK
# 8   0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c     ETHK
# 9   0xab0d1578216a545532882e420a8c61ea07b00b12      KST
# 10  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 11  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c     ETHK
# 12  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 13  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 14  0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85     USDC
# 15  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 16  0xdcac52e001f5bd413aa6ea83956438f29098166b     USDK
# 17  0x8179d97eb6488860d816e3ecafe694a4153f216c      CHE
# 18  0x5fac926bf1e638944bb16fb5b787b5ba4bc85b0a       JF
# 19  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 20  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 21  0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85     USDC
# 22  0x8f8526dbfd6e38e3d8307702ca8469bae6c56c15     WOKT
# 23  0x5fac926bf1e638944bb16fb5b787b5ba4bc85b0a       JF
# 24  0xc946daf81b08146b1c7a8da2a851ddf2b3eaaf85     USDC
# 25  0xef71ca2ee68f45b9ad6f72fbdb33d707b872315c     ETHK
#
#                    arbLabel
# 0     USDT=>WOKT=>OKB=>USDT
# 1     USDT=>KLT=>WOKT=>USDT
# 2    USDT=>BTCK=>ETHK=>USDT
# 3    USDT=>WOKT=>USDK=>USDT
# 4   USDT=>CASH=>SHARE=>USDT
# 5      USDT=>JF=>YYDS=>USDT
# 6     USDT=>USDK=>OKB=>USDT
# 7    USDT=>USDC=>USDK=>USDT
# 8    USDT=>WOKT=>ETHK=>USDT
# 9     USDT=>WOKT=>KST=>USDT
# 10    USDT=>PND=>WOKT=>USDT
# 11    USDT=>CHE=>ETHK=>USDT
# 12    USDT=>CHE=>WOKT=>USDT
# 13     USDT=>JF=>WOKT=>USDT
# 14   USDT=>Celt=>USDC=>USDT
# 15   USDT=>DAIK=>WOKT=>USDT
# 16   USDT=>BTCK=>USDK=>USDT
# 17    USDT=>BTCK=>CHE=>USDT
# 18      USDT=>AST=>JF=>USDT
# 19    USDT=>BFI=>WOKT=>USDT
# 20   USDT=>SFGK=>WOKT=>USDT
# 21    USDT=>OFI=>USDC=>USDT
# 22    USDT=>OFI=>WOKT=>USDT
# 23   USDT=>SQUIDK=>JF=>USDT
# 24   USDT=>DAIK=>USDC=>USDT
# 25   USDT=>USDK=>ETHK=>USDT
